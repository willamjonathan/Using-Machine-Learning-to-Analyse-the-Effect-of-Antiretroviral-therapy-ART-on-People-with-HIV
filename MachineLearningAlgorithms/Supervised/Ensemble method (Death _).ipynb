# %%
# importing utility modules

import pandas as pd

from sklearn.metrics import classification_report, confusion_matrix

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score, confusion_matrix

# importing machine learning models for prediction

from sklearn.ensemble import RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier

from sklearn.svm import  SVC

from xgboost import XGBClassifier

from sklearn.linear_model import LogisticRegression
 
# importing voting classifier

from sklearn.ensemble import VotingClassifier
 
# loading train data set in dataframe from train_data.csv file



df = pd.read_csv("FinalResult.csv")
df['Index'] = 1
df.loc[df['Death (%)']<= 4	,'Index'] =0 
X= df [['ART (%)', 'People with HIV']]
y= df ['Index']

y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 820    0
# 821    0
# 822    1
# 823    1
# 824    0
# Name: Index, Length: 825, dtype: int64

# %%
# df.describe()
# import matplotlib.pyplot as plt
# fig, ax = plt.subplots()
# ax.hist(y, bins = [0,4,6,8])

# %%
#  Splitting between train data into training and validation dataset

X_train, X_test, y_train, y_test = train_test_split(

    X, y, test_size=0.33)
 
# initializing all the model objects with default parameters

model_1 = LogisticRegression(C=0.1, random_state=42, solver='newton-cg')

model_2 = XGBClassifier(alpha=10, learning_rate=1.0, max_depth=4)

model_3 = RandomForestClassifier(n_estimators = 500)

# model_4  =SVC(C=100, gamma=0.1, kernel = "rbf",random_state=42)

model_5 = KNeighborsClassifier(n_neighbors=21)

model_6 = DecisionTreeClassifier(
            criterion = "entropy", random_state = 100,
            max_depth = 5, min_samples_leaf = 10)
 
# Making the final model using voting classifier

final_model = VotingClassifier(

    estimators=[('lr', model_1), ('KNN', model_5),('dt', model_6)], voting='soft')
 
# training all the model on the train dataset
final_model.fit(X_train, y_train)
 
# predicting the output on the test dataset

pred_final = final_model.predict(X_test)
 
# printing log loss between actual and predicted value
print("Train accuracy: ",accuracy_score(y_train, final_model.predict(X_train)))
print("Test accuracy: ",accuracy_score(y_test, pred_final))
print("---------------------------------------------------------")
print(classification_report(y_train, final_model.predict(X_train)))
print(classification_report(y_test, pred_final))
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:327: LineSearchWarning: The line search algorithm did not converge
#   warn('The line search algorithm did not converge', LineSearchWarning)
# /usr/local/lib/python3.8/dist-packages/scipy/optimize/linesearch.py:478: LineSearchWarning: The line search algorithm did not converge
# ...

# %% [markdown]
# FROM 5 testing, the best result:

# %% [markdown]
# ![BEST 5- ensemble - death.png](data:image/png;base64,...)

# %% [markdown]
# <!-- FROM 5, best result -->
# 1.
# Train accuracy: 0.9021739130434783
# Test accuracy: 0.8681318681318682
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90       293
#            1       0.87      0.93      0.90       259
#
#     accuracy                           0.90       552
#    macro avg       0.90      0.90      0.90       552
# weighted avg       0.90      0.90      0.90       552
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88       153
#            1       0.84      0.87      0.85       120
#
#     accuracy                           0.87       273
#    macro avg       0.87      0.87      0.87       273
# weighted avg       0.87      0.87      0.87       273
# 2.
# Train accuracy: 0.8894927536231884
# Test accuracy: 0.8827838827838828
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       290
#            1       0.86      0.92      0.89       262
#
#     accuracy                           0.89       552
#    macro avg       0.89      0.89      0.89       552
# weighted avg       0.89      0.89      0.89       552
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89       156
#            1       0.81      0.95      0.87       117
#
#     accuracy                           0.88       273
#    macro avg       0.88      0.89      0.88       273
# weighted avg       0.89      0.88      0.88       273
# 3.
# Train accuracy:  0.9057971014492754
# Test accuracy:  0.8717948717948718
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91       292
#            1       0.89      0.91      0.90       260
#
#     accuracy                           0.91       552
#    macro avg       0.91      0.91      0.91       552
# weighted avg       0.91      0.91      0.91       552
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89       154
#            1       0.88      0.82      0.85       119
#
#     accuracy                           0.87       273
#    macro avg       0.87      0.87      0.87       273
# weighted avg       0.87      0.87      0.87       273
# 4.
# Train accuracy:  0.9094202898550725
# Test accuracy:  0.9084249084249084
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       294
#            1       0.90      0.90      0.90       258
#
#     accuracy                           0.91       552
#    macro avg       0.91      0.91      0.91       552
# weighted avg       0.91      0.91      0.91       552
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92       152
#            1       0.88      0.93      0.90       121
#
#     accuracy                           0.91       273
#    macro avg       0.91      0.91      0.91       273
# weighted avg       0.91      0.91      0.91       273
# 5.
# Train accuracy:  0.9148550724637681
# Test accuracy:  0.8717948717948718
# ---------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92       300
#            1       0.91      0.90      0.91       252
#
#     accuracy                           0.91       552
#    macro avg       0.91      0.91      0.91       552
# weighted avg       0.91      0.91      0.91       552
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.92      0.88       146
#            1       0.90      0.82      0.86       127
#
#     accuracy                           0.87       273
#    macro avg       0.88      0.87      0.87       273
# weighted avg       0.87      0.87      0.87       273
