# %%
# Import those libraries
import pandas as pd
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %% [markdown]
# Using pearson test is used to measure linear correlation

# %%
# Import your data into Python
df = pd.read_csv("FinalResult.csv")
df1 = df[df['Total Population']>19000000]
df2 = df[df['Total Population']<19000000]
# Convert dataframe into series
list1 = df['Death (%)']
list2 = df['ART (%)']
corr, _ = pearsonr(list1, list2)

print('Pearsons correlation: %.3f' % corr)
list1 = df1['Death (%)']
list2 = df1['ART (%)']
corr, _ = pearsonr(list1, list2)

print('Pearsons correlation: %.3f' % corr)
list1 = df2['Death (%)']
list2 = df2['ART (%)']
# Apply the pearsonr()
corr, _ = pearsonr(list1, list2)

print('Pearsons correlation: %.3f' % corr)

# This code is contributed by Amiya Rout
# Out:
# Pearsons correlation: -0.319
# Pearsons correlation: -0.652
# Pearsons correlation: -0.316

# %%
plt.scatter(df1['Death (%)'],df1['ART (%)'])
plt.xlabel('Death (%)')
plt.ylabel('ART (%)')
# Out:
# Text(0, 0.5, 'ART (%)')

# %%
plt.scatter(df2['Death (%)'],df2['ART (%)'])
plt.xlabel('Death (%)')
plt.ylabel('ART (%)')
# Out:
# Text(0, 0.5, 'ART (%)')

# %% [markdown]
# The negative result shows that when one variable changes, the other variable changes in the opposite direction.
